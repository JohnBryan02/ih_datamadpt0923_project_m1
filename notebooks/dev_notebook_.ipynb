# %% [markdown]
# ### dev_notebook_
#
# This is your development environment...you may start:
# - Exploring your data.
# - Testing the ad-hoc methods.
# - Designing your pipeline.

# %%
import pandas as pd
import requests
import bs4

# %%
df = pd.read_csv('../data/bicimad_stations.csv', sep = '\t')
df.head(10)
# Out:
#    Unnamed: 0  id                     name  light number  \
# 0           0   1    1a - Puerta del Sol A      3     1a
# 1           1   2    1b - Puerta del Sol B      3     1b
# 2           2   3          2 - Miguel Moya      3      2
# 3           3   4   3 - Plaza Conde Suchil      2      3
# 4           4   5             4 - Malasaña      1      4
# 5           5   6           5 - Fuencarral      1      5
# 6           6   7  6 - Colegio Arquitectos      3      6
# 7           7   8            7 - Hortaleza      3      7
# 8           8   9      8 - Alonso Martínez      1      8
# 9           9  10  9 - Plaza de San Miguel      2      9
#
#                                     address  activate  no_available  \
# 0                       Puerta del Sol nº 1         1             1
# 1                       Puerta del Sol nº 1         1             1
# 2                    Calle Miguel Moya nº 1         1             1
# ...

# %%
df2 = pd.read_csv('../data/bicipark_stations.csv', sep = ';')
df2.head()
# Out:
#    Unnamed: 0  stationId                 stationName  \
# 0           0         74  Bicipark Fuente de la Mora
# 1           1         22             Bicipark Orense
# 2           2         49          Bicipark Montalban
# 3           3         12            Bicipark Almagro
# 4           4          9          Bicipark Recoletos
#
#                          address     city zip_code  total_places  free_places  \
# 0  Estación de Fuente de la Mora   Madrid    28050            10            9
# 1      Avenida General Perón, 27   Madrid    28020            15            9
# 2          Calle de Montalbán, 5   Madrid    28014            16           15
# 3              Calle Almagro, 11   Madrid    28010            16           12
# 4          Paseo de Recoletos, 2   Madrid    28001            10            3
#
#    enabled  reserved_places geometry.type      geometry.coordinates
# 0        1                0         Point  [-3.6630679, 40.4846838]
# ...

# %%
# tenemos que sseparar las coordenadas en latitud y longitud (- en negativo)

# %% [markdown]
# # DESCARGA DEL JSON

# %%
url = 'https://datos.madrid.es/egob/dataset/'
dataset_id = '200304-0-centros-culturales'
url2 = f'{url}{dataset_id}.json'
response = requests.get(url2)
response.content

# %%
response.content
# Out:
# b'\n<!DOCTYPE html>\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n<!--[if IE 8]>         <html class="no-js ie8" lang="es" xml:lang="es"> <![endif]-->\r\n<!--[if gt IE 8]><!--> <html class="no-js" lang="es" xml:lang="es"> <!--<![endif]-->\r\n\t\r\n<head>\r\n<meta content="IE=Edge" http-equiv="X-UA-Compatible">\r\n\r\n\t\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\t\r\n\t\r\n\t\t\r\n\t\r\n\r\n\r\n<title>Conjuntos de datos - Portal de datos abiertos del Ayuntamiento de Madrid</title>\r\n\r\n\r\n\r\n\r\n<meta name="description" content="Portal de datos abiertos del Ayuntamiento de Madrid - Conjuntos de datos" />\r\n<meta http-equiv="Content-Type" content="text/html; charset=utf-8" >\r\n<meta name="viewport" content="width=device-width, initial-scale=1">\r\n\r\n<meta property="og:description" content="Portal de datos abiertos del Ayuntamiento de Madrid - Conjuntos de datos" >\r\n<meta name="twitt
# ...

# %%
response_json = response.json()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~\miniconda3\envs\pm1\lib\site-packages\requests\models.py:971, in Response.json(self, **kwargs)
#     970 try:
# --> 971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File ~\miniconda3\envs\pm1\lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# ...

# %%
parsed_html = bs4.BeautifulSoup(html,"html.parser")

# %%
parsed_html
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="x-ua-compatible"/>
# <title>Swagger UI</title>
# <link href="images/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="images/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="css/typography.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="css/reset.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="css/screen.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="css/reset.css" media="print" rel="stylesheet" type="text/css"/>
# <link href="css/print.css" media="print" rel="stylesheet" type="text/css"/>
# <link href="css/madrid.css" media="screen" rel="stylesheet" type="text/css"/>
# <script src="lib/object-assign-pollyfill.js" type="text/javascript"></script>
# <script src="lib/jquery-1.8.0.min.js" type="text/javascript"></script>
# ...
